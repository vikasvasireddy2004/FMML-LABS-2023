# %% [markdown]
# <a href="https://colab.research.google.com/github/vikasvasireddy2004/FMML-LABS-2023/blob/main/Mod_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 11:56:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   111MB/s    in 0.6s
#
# 2024-04-05 11:56:17 (111 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5193    1110.3076v1  We consider the problem of covariance matrix e...  stat
# 22685  1704.04031v1  Matrix factorisation methods decompose multiva...  stat
# 6224   1609.08976v1  A novel variational autoencoder is developed t...  stat
# 35354  cs/0411035v1  Given a user-specified minimum correlation thr...    cs
# 10934   1112.2315v1  It is now well known that decentralised optimi...  stat
# ...             ...                                                ...   ...
# 37852   0902.1323v1  In this paper we propose a computationally eff...  stat
# 28607  1707.02406v1  In this paper, a level-wise mixture model (LMM...    cs
# 29812  1710.07168v1  Visual speech recognition is a challenging res...    cs
# 21591   1106.2474v1  Due to space limitations, our submission "Sour...  stat
# 17391  1710.10504v2  Attention models have been intensively studied...    cs
#
#                                                    title  year  \
# 5193   Efficient Latent Variable Graphical Model Sele...  2011
# 22685         Infinite Sparse Structured Factor Analysis  2017
# 6224   Variational Autoencoder for Deep Learning of I...  2016
# 35354  A FP-Tree Based Approach for Mining All Strong...  2004
# 10934         Adaptive Forgetting Factor Fictitious Play  2011
# ...                                                  ...   ...
# 37852  Sparse partial least squares for on-line varia...  2009
# 28607  Embedding Visual Hierarchy with Deep Networks ...  2017
# 29812  Combining Multiple Views for Visual Speech Rec...  2017
# 21591  Source Separation and Clustering of Phase-Lock...  2011
# 17391  Phase Conductor on Multi-layered Attentions fo...  2017
#
#                                                 keywords
# 5193   [covariance, estimation, variables, conditions...
# 22685  [factorisation, decompose, multivariate, obser...
# 6224   [variational, autoencoder, developed, associat...
# 35354  [specified, correlation, threshold, transactio...
# 10934  [decentralised, optimisation, formulated, pote...
# ...                                                  ...
# 37852  [computationally, efficient, algorithm, select...
# 28607  [developed, embedding, hierarchy, recognition,...
# 29812  [recognition, challenging, particular, practic...
# 21591  [limitations, submission, separation, clusteri...
# 17391  [attention, intensively, comprehension, attent...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5193     [covariance, estimation, variables, conditions...
# 22685    [factorisation, decompose, multivariate, obser...
# 6224     [variational, autoencoder, developed, associat...
# 35354    [specified, correlation, threshold, transactio...
# 10934    [decentralised, optimisation, formulated, pote...
#                                ...
# 22683    [interpretation, importance, autoencoders, lik...
# 13007    [processing, applications, applications, expre...
# 22946    [factorization, technique, representations, co...
# 9942     [bipartite, instances, instances, bipartite, o...
# 7521     [processes, structure, parametric, application...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8791 words.
# Out of those 4542 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d27a897b-3d0d-4001-bf57-2b5e8c3ee4f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d27a897b-3d0d-4001-bf57-2b5e8c3ee4f9")) {                    Plotly.newPlot(                        "d27a897b-3d0d-4001-bf57-2b5e8c3ee4f9",                        [{"x":["efficient","concentration","structure","marginalization","involving","decomposed","variables","thousands","guaranteed","estimation","artificial","correlation","expression","covariance","explained","significantly","algorithm","conditions","graphical","selection","tractable","structures","smoothness","tractability","combinations","appropriate","characteristics","simulations","approximation","accurately","reconstruction","regularised","sufficient","challenge","independent","decompose","observations","factorisation","denoising","essential","presented","computational","neuroimaging","representing","structured","demonstrate","multivariate","consequence","supervised","autoencoder","manifested","generative","predicting","distribution","framework","deconvolutional","convolutional","performed","associated","approximate","presenceabsence","averaging","variational","computationally","unsupervised","developed","specified","previously","practical","experimental","generation","transaction","threshold","transactions","coefficients","performance","synthetic","technique","correlated","specifications","candidate","heuristic","techniques","fictitious","strategies","formulated","geometric","potential","convergence","algorithms","stochastic","management","opponents","variations","strategic","assumption","stationary","assignment","variation","optimisation","adaptively","theoretical","therefore","realistic","forgetting","decentralised","streaming","literature","condition","definiteness","positively","arbitrary","dependencies","regularization","constraints","generalizations","parametric","parameter","regressions","exponential","distributions","likelihood","generalization","motivation","univariate","detection","multiresolution","kronecker","modifications","anomalous","applicability","introducing","competitive","available","deviations","anomalies","university","normative","representation","decompositions","reduction","efficiency","dimension","detecting","considered","experiments","requiring","polyhedral","supplement","restricting","constraint","intermediate","cumulative","validating","knowledge","violations","satisfied","accumulated","respectively","optimization","contributions","heuristics","probability","successes","encountered","difficulties","incorporates","probabilistic","competition","engineering","implementation","resulting","optimized","transforming","objective","inclusion","computation","encouraging","parameters","inference","incorporate","principled","differentiable","conditional","regularizer","determine","straightforward","interesting","collectively","surprisingly","effectiveness","collection","ontologies","significant","parallelizing","description","efficiently","scalability","distributing","simplicity"],"y":[434,12,341,4,50,11,118,34,35,216,131,71,37,17,9,269,839,142,54,194,33,152,12,13,41,77,96,41,120,65,125,0,70,134,136,10,74,2,53,73,159,276,3,60,118,542,24,17,180,35,2,127,81,227,552,0,355,110,104,110,0,21,57,102,131,199,33,92,143,393,158,7,33,5,36,883,145,253,29,12,53,76,344,2,103,32,63,174,126,630,126,42,2,74,4,73,28,23,59,23,26,149,167,69,7,1,12,116,43,0,4,82,48,79,141,8,32,126,0,49,141,68,110,21,7,345,2,1,15,5,39,44,122,294,6,8,14,3,391,11,107,159,72,82,125,594,52,1,3,5,85,35,16,8,361,5,13,7,78,341,48,45,173,14,20,31,38,163,32,54,134,154,57,9,176,12,144,22,236,198,68,29,18,100,23,66,22,64,4,34,195,64,25,247,6,78,165,30,4,16],"type":"bar"},{"x":["efficient","concentration"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4542,), (4542, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.6210045662100456);'>Convolutional</span> <span style=''>Features</span> <span style=''>for</span> <span style=''>Image</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.6124031007751938);'>Retrieval</span> <span style=''>and</span> <span style=''>Scene</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>Categorization</span> <br/><br/><span style=''>Several</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>showed</span> <span style=''>how</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.37869822485207105);'>representations</span> <span style=''>learned</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.6210045662100456);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>can</span> <span style=''>be</span> <span style=''>repurposed</span> <span style=''>for</span> <span style=''>novel</span> <span style=''>tasks</span> <span style=''>Most</span> <span style=''>commonly</span> <span style=''>it</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activation</span> <span style=''>features</span> <span style=''>of</span> <span style=''>the</span> <span style=''>last</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.30841121495327106);'>connected</span> <span style=''>layers</span> <span style=''>(fc7</span> <span style=''>or</span> <span style=''>fc6)</span> <span style=''>of</span> <span style=''>the</span> <span style=''>network</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>on</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.6525612472160356);'>recognition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>datasets</span> <span style=''>Instead</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6525612472160356);'>recognition</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>the</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6124031007751938);'>retrieval</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>examines</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>pooling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strategies</span> <span style=''>derived</span> <span style=''>for</span> <span style=''>CNN</span> <span style=''>features</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>presented</span> <span style=''>scheme</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>features</span> <span style=''>maps</span> <span style=''>from</span> <span style=''>an</span> <span style=''>earlier</span> <span style=''>layer</span> <span style=''>5</span> <span style=''>of</span> <span style=''>the</span> <span style=''>CNN</span> <span style='background-color:rgba(0, 255, 0, 0.5151515151515151);'>architecture</span> <span style=''>which</span> <span style=''>has</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>preserve</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Fixed</span> <span style=''>Point</span> <span style=''>of</span> <span style=''>View</span> <span style=''>on</span> <span style=''>Gradient</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Big</span> <span style=''>Data</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Interpreting</span> <span style=''>gradient</span> <span style=''>methods</span> <span style=''>as</span> <span style=''>fixed</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>detailed</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>those</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conceptual</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simplicity</span> <span style=''>gradient</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>massive</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>(big</span> <span style=''>data)</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>the</span> <span style=''>de</span> <span style=''>facto</span> <span style=''>standard</span> <span style=''>for</span> <span style=''>training</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Studying</span> <span style=''>gradient</span> <span style=''>methods</span> <span style=''>within</span> <span style=''>the</span> <span style=''>realm</span> <span style=''>of</span> <span style=''>fixed</span> <span style=''>point</span> <span style=''>theory</span> <span style=''>provides</span> <span style=''>us</span> <span style=''>with</span> <span style=''>powerful</span> <span style=''>tools</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>gradient</span> <span style=''>methods</span> <span style=''>using</span> <span style=''>inexact</span> <span style=''>or</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>can</span> <span style=''>be</span> <span style=''>studied</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conveniently</span> <span style=''>using</span> <span style=''>well</span> <span style=''>known</span> <span style=''>results</span> <span style=''>on</span> <span style=''>inexact</span> <span style=''>fixed</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Partition</span> <span style=''>Function</span> <span style=''>and</span> <span style=''>Random</span> <span style=''>Maximum</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Posteriori</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Perturbations</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>relate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>to</span> <span style=''>the</span> <span style=''>max</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.39641943734015345);'>variables</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximating</span> <span style=''>and</span> <span style=''>bounding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>using</span> <span style=''>MAP</span> <span style='background-color:rgba(255, 0, 0, 0.32307692307692304);'>inference</span> <span style=''>on</span> <span style=''>randomly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbed</span> <span style=''>models</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>we</span> <span style=''>can</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>MAP</span> <span style=''>solvers</span> <span style=''>such</span> <span style=''>as</span> <span style=''>graph</span> <span style=''>cuts</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>excels</span> <span style=''>in</span> <span style=''>the</span> <span style=''>typical</span> <span style=''>high</span> <span style=''>signal</span> <span style=''>high</span> <span style=''>coupling</span> <span style=''>regime</span> <span style=''>that</span> <span style=''>results</span> <span style=''>in</span> <span style=''>ragged</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>landscapes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Dynamic</span> <span style=''>Bidding</span> <span style=''>for</span> <span style=''>Advance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Commitments</span> <span style=''>in</span> <span style=''>Truckload</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Brokerage</span> <span style=''>Markets</span> <br/><br/><span style=''>Truckload</span> <span style=''>brokerages</span> <span style=''>a</span> <span style=''>100</span> <span style=''>billionyear</span> <span style=''>industry</span> <span style=''>in</span> <span style=''>the</span> <span style=''>US</span> <span style=''>plays</span> <span style=''>the</span> <span style=''>critical</span> <span style=''>role</span> <span style=''>of</span> <span style=''>matching</span> <span style=''>shippers</span> <span style=''>with</span> <span style=''>carriers</span> <span style=''>often</span> <span style=''>to</span> <span style=''>move</span> <span style=''>loads</span> <span style=''>several</span> <span style=''>days</span> <span style=''>into</span> <span style=''>the</span> <span style=''>future</span> <span style=''>Brokerages</span> <span style=''>not</span> <span style=''>only</span> <span style=''>have</span> <span style=''>to</span> <span style=''>find</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>companies</span> <span style=''>that</span> <span style=''>will</span> <span style=''>agree</span> <span style=''>to</span> <span style=''>move</span> <span style=''>a</span> <span style=''>load</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>brokerage</span> <span style=''>often</span> <span style=''>has</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>price</span> <span style=''>that</span> <span style=''>both</span> <span style=''>the</span> <span style=''>shipper</span> <span style=''>and</span> <span style=''>carrier</span> <span style=''>will</span> <span style=''>agree</span> <span style=''>to</span> <span style=''>The</span> <span style=''>price</span> <span style=''>not</span> <span style=''>only</span> <span style=''>varies</span> <span style=''>by</span> <span style=''>shipper</span> <span style=''>and</span> <span style=''>carrier</span> <span style=''>but</span> <span style=''>also</span> <span style=''>by</span> <span style=''>the</span> <span style=''>traffic</span> <span style=''>lanes</span> <span style=''>and</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>commodity</span> <span style=''>type</span> <span style=''>Brokerages</span> <span style=''>have</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>about</span> <span style=''>shipper</span> <span style=''>and</span> <span style=''>carrier</span> <span style=''>response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>by</span> <span style=''>offering</span> <span style=''>a</span> <span style=''>price</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observing</span> <span style=''>whether</span> <span style=''>each</span> <span style=''>accepts</span> <span style=''>the</span> <span style=''>quote</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>gradient</span> <span style=''>policy</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contextual</span> <span style=''>settings</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09337134711332858)
# 	experimental (0.14005702066999287)
# 	segmentation (0.06664290805416964)
# 	knowledge (0.1286528866714184)
# 	representation (0.13934426229508196)
# 	information (0.2466143977191732)
# 	detection (0.12295081967213115)
# 	different (0.2690662865288667)
# 	convolutional (0.12651461154668567)
# 	recognition (0.1322166785459729)
#
# Some Statistics words are:
# 	algorithm (0.3831494483450351)
# 	stochastic (0.13139418254764293)
# 	variables (0.13691073219658978)
# 	statistical (0.1584754262788365)
# 	theoretical (0.15446339017051153)
# 	distribution (0.18655967903711135)
# 	estimation (0.18455366098294884)
# 	inference (0.19408224674022065)
# 	dimensional (0.1945837512537613)
# 	regression (0.1860581745235707)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5c04abde-d2b1-4eca-9e8e-883305f08ccf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c04abde-d2b1-4eca-9e8e-883305f08ccf")) {                    Plotly.newPlot(                        "5c04abde-d2b1-4eca-9e8e-883305f08ccf",                        [{"x":["efficient","concentration","structure","marginalization","involving","decomposed","variables","thousands","guaranteed","estimation","artificial","correlation","expression","covariance","explained","significantly","algorithm","conditions","graphical","selection","tractable","structures","smoothness","tractability","combinations","appropriate","characteristics","simulations","approximation","accurately","reconstruction","regularised","sufficient","challenge","independent","decompose","observations","factorisation","denoising","essential","presented","computational","neuroimaging","representing","structured","demonstrate","multivariate","consequence","supervised","autoencoder","manifested","generative","predicting","distribution","framework","deconvolutional","convolutional","performed","associated","approximate","presenceabsence","averaging","variational","computationally","unsupervised","developed","specified","previously","practical","experimental","generation","transaction","threshold","transactions","coefficients","performance","synthetic","technique","correlated","specifications","candidate","heuristic","techniques","fictitious","strategies","formulated","geometric","potential","convergence","algorithms","stochastic","management","opponents","variations","strategic","assumption","stationary","assignment","variation","optimisation","adaptively","theoretical","therefore","realistic","forgetting","decentralised","streaming","literature","condition","definiteness","positively","arbitrary","dependencies","regularization","constraints","generalizations","parametric","parameter","regressions","exponential","distributions","likelihood","generalization","motivation","univariate","detection","multiresolution","kronecker","modifications","anomalous","applicability","introducing","competitive","available","deviations","anomalies","university","normative","representation","decompositions","reduction","efficiency","dimension","detecting","considered","experiments","requiring","polyhedral","supplement","restricting","constraint","intermediate","cumulative","validating","knowledge","violations","satisfied","accumulated","respectively","optimization","contributions","heuristics","probability","successes","encountered","difficulties","incorporates","probabilistic","competition","engineering","implementation","resulting","optimized","transforming","objective","inclusion","computation","encouraging","parameters","inference","incorporate","principled","differentiable","conditional","regularizer","determine","straightforward","interesting","collectively","surprisingly","effectiveness","collection","ontologies","significant","parallelizing","description","efficiently","scalability","distributing","simplicity","evaluation","independence","empirical","intensive","intractable","computations","subsumption","reasoning","answering","converting","applications","recognition","investigated","properties","different","transform","statistical","difficult","verification","identification","sequential","authentication","traditional","extensive","important","nonlinear","dependent","partially","feedforward","effective","hyperparameter","facilitate","sometimes","piecewise","functions","improvement","violation","broadband","allocation","requirements","concerned","locations","determines","connected","designing","distributed","communication","processes","application","communications","extensively","simulate ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	regularised
# 	deconvolutional
# 	presenceabsence
# 	definiteness
# 	regressions
# 	interpolate
# 	supersparse
# 	compresses
# 	metropolis
# 	manifests
# 	worthwhile
# 	spectrometry
# 	blackwellized
# 	applicants
# 	representer
# 	sentinels
# 	infectious
# 	hausdorff
# 	geostatistical
# 	clarified
# Some words which never appear in Statistics papers:
# 	subsumption
# 	broadband
# 	impressions
# 	societies
# 	binarization
# 	continued
# 	accelerators
# 	pioneering
# 	observers
# 	unordered
# 	axiomatization
# 	multiagent
# 	ecological
# 	transmitted
# 	implementable
# 	benchmarked
# 	earthquake
# 	keyframes
# 	attractiveness
# 	derivable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0672964848782285e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7525
